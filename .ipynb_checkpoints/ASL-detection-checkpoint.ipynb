# %% [markdown]
# # ASL Sign Alphabet Detection

# %% [markdown]
# ![test_img.png](attachment:1af09833-8361-4a51-90ee-b57c8a46830a.png)

# %%
# !pip install opencv-python mediapipe numpy pandas matplotlib tensorflow

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('Dataset/train_data.csv')
test = pd.read_csv('Dataset/test_data.csv')

# %%
train.head()
# Out:
#   label    ver.x0    ver.y0        ver.z0    ver.x1    ver.y1    ver.z1  \
# 0     A  0.278411  0.695334 -6.762847e-07  0.200128  0.620533 -0.022475
# 1     A  0.291353  0.795231 -1.576762e-06  0.171733  0.662912 -0.022622
# 2     A  0.286198  0.796218 -1.572270e-06  0.166102  0.672183 -0.023547
# 3     A  0.281822  0.814402 -1.660732e-06  0.162763  0.683275 -0.021745
# 4     A  0.281047  0.806833 -1.637994e-06  0.160198  0.691229 -0.024537
#
#      ver.x2    ver.y2    ver.z2  ...   ver.z17   ver.x18   ver.y18   ver.z18  \
# 0  0.142370  0.516582 -0.040151  ... -0.049513  0.365731  0.458294 -0.073240
# 1  0.101379  0.512875 -0.044181  ... -0.075002  0.402795  0.452170 -0.114728
# 2  0.093100  0.524100 -0.046151  ... -0.079710  0.393102  0.463676 -0.120484
# 3  0.089101  0.537056 -0.046123  ... -0.079134  0.386263  0.468952 -0.117127
# 4  0.082758  0.548465 -0.049812  ... -0.079054  0.380947  0.475781 -0.122076
#
#     ver.x19   ver.y19   ver.z19   ver.x20   ver.y20   ver.z20
# ...

# %%
test.head()
# Out:
#   label    ver.x0    ver.y0        ver.z0    ver.x1    ver.y1    ver.z1  \
# 0     A  0.695636  0.320236 -6.424395e-07  0.611387  0.286212 -0.026116
# 1     A  0.698420  0.320158 -7.357888e-07  0.604790  0.293412 -0.018377
# 2     A  0.644498  0.363841 -5.295008e-07  0.576312  0.317124 -0.025761
# 3     A  0.609387  0.343991 -5.997089e-07  0.536886  0.309122 -0.031247
# 4     A  0.551318  0.354593 -5.251707e-07  0.470017  0.308904 -0.014689
#
#      ver.x2    ver.y2    ver.z2  ...   ver.z17   ver.x18   ver.y18   ver.z18  \
# 0  0.533874  0.233874 -0.044348  ... -0.037806  0.734015  0.097736 -0.062217
# 1  0.528247  0.241065 -0.032291  ... -0.039490  0.731618  0.110540 -0.061796
# 2  0.511956  0.253168 -0.041103  ... -0.026967  0.712215  0.141546 -0.045297
# 3  0.465864  0.250483 -0.046370  ... -0.036492  0.658616  0.168759 -0.057992
# 4  0.398517  0.257831 -0.024332  ... -0.018492  0.585101  0.137656 -0.034431
#
#     ver.x19   ver.y19   ver.z19   ver.x20   ver.y20   ver.z20
# ...

# %%
labels = test['label'].values
unique_labels, counts = np.unique(labels, return_counts=True)

# %%
plt.figure()
plt.bar(unique_labels, counts)
plt.xlabel('Label')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
num_classes = len(unique_labels)
num_epochs = 20
batch_size = 128

# %%
l = train['label'].tolist()
y_train = [ord(label) - ord('A') for label in l]
x_train = []
for i, row in train.iterrows():
    features = row.drop('label').values
    x_train.append(features)

# %%
l = test['label'].tolist()
y_test = [ord(label) - ord('A') for label in l]
x_test = []
for i, row in test.iterrows():
    features = row.drop('label').values
    x_test.append(features)

# %%
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# %%
x_train = np.array(x_train, dtype='float32')
x_test = np.array(x_test, dtype='float32')

# %%
y_train.shape
# Out:
# (26000, 26)

# %%
x_train.shape
# Out:
# (26000, 63)

# %%
model = Sequential()

model.add(Dense(units=256, activation='relu', input_shape=(63,)))
model.add(Dropout(0.5))

model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 256)               16384
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 26)                1690
#
# ...
# Total params: 59226 (231.35 KB)
# Trainable params: 59226 (231.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 204/204 [==============================] - 1s 2ms/step - loss: 2.8979 - accuracy: 0.1246 - val_loss: 1.9634 - val_accuracy: 0.4260
# Epoch 2/20
# 204/204 [==============================] - 0s 2ms/step - loss: 1.6289 - accuracy: 0.4290 - val_loss: 0.9383 - val_accuracy: 0.7022
# Epoch 3/20
# 204/204 [==============================] - 0s 2ms/step - loss: 1.0498 - accuracy: 0.6076 - val_loss: 0.7323 - val_accuracy: 0.7655
# Epoch 4/20
# 204/204 [==============================] - 0s 2ms/step - loss: 0.8135 - accuracy: 0.6940 - val_loss: 0.6541 - val_accuracy: 0.8329
# Epoch 5/20
# 204/204 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.7467 - val_loss: 0.6047 - val_accuracy: 0.8255
# Epoch 6/20
# 204/204 [==============================] - 0s 2ms/step - loss: 0.6107 - accuracy: 0.7749 - val_loss: 0.5768 - val_accuracy: 0.8368
# Epoch 7/20
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Accuracy")
plt.xlabel('epoch')
plt.ylabel('accuracy')

plt.legend(['train', 'test'])

plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Loss")
plt.xlabel('epoch')
plt.ylabel('loss')

plt.legend(['train', 'test'])

plt.show()

# %%
model.save("ASL-detection-model.keras")

# %%
import cv2
import mediapipe as mp

# %%
model = load_model("ASL-detection-model.keras")

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
def mediapipe(frame, hands):
    frame = cv2.resize(cv2.flip(frame, 1), (640, 480))
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    image.flags.writeable = False
    results = hands.process(image)
    image.flags.writeable = True

    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    return image, results

# %%
capture = cv2.VideoCapture(0)

# %%
with mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.5, min_tracking_confidence=0.5) as hands:
    while capture.isOpened():
        ret, frame = capture.read()

        image, results = mediapipe(frame, hands)

        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(
                    image, 
                    hand_landmarks, 
                    mp_hands.HAND_CONNECTIONS,
                )

        if results.multi_handedness:
            if results.multi_handedness[0].classification[0].label == "Right":
                for hand_landmarks in results.multi_hand_landmarks:
                    landmarks = np.array([[lmk.x, lmk.y, lmk.z] for lmk in hand_landmarks.landmark]).flatten()

                    input_data = np.reshape(landmarks, (1, -1))

                    predicted_probabilities = model.predict(input_data)
                    predicted_class = np.argmax(predicted_probabilities)
                    predicted_letter = chr(ord('A') + int(predicted_class))

                    cv2.putText(image, predicted_letter, (10, 30), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 0, 0), 2)
        
        cv2.imshow("Hand Tracking", image)

        if cv2.waitKey(5) & 0xFF == 27:
            break

    capture.release()
    cv2.destroyAllWindows()
